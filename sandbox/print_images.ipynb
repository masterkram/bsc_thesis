# %%
import matplotlib.pyplot as plt
import numpy as np
import os

# %% [markdown]
# ## Satellite Examples

# %%
out = '../logs/res/'

# %%
satFiles = os.listdir('../data/preprocessed/satellite/')

# %%
satexample = np.load(f"../data/preprocessed/satellite/{satFiles[20]}")

# %% [markdown]
# During night

# %%
channels = [
      "VIS006",
  "VIS008",
  "IR_016",
  "IR_039",
  "IR_087",
  "IR_097",
  "IR_108",
  "IR_120",
  "IR_134",

  "WV_062",
  "WV_073",]

cmapss= [
    'Blues',
    'Blues',
    'bone',
    'bone',
    'bone',
    'bone',
    'bone',
    'bone',
    'bone',
    'bone',
    'bone',
]

# %%
fig, axes = plt.subplots(4, 3,figsize=(10,15), constrained_layout=True,sharex=True, sharey=False)
for i in range(4):
    for j in range(3):
        if (i * 3 + j < 11):
          axes[i][j].imshow(satexample[i * 3 + j], cmap="Blues")
          axes[i][j].set_title(channels[i*3+j], font="monospace")
        axes[i][j].axis('off')

# %%
plt.imshow(satexample[0], cmap='summer')
plt.grid()
plt.axis('off')
plt.tight_layout()

# %%
plt.imshow(satexample[10], cmap='Spectral')
plt.grid()
plt.axis('off')
plt.tight_layout()

# %%
radFiles = os.listdir('../data/preprocessed/radar/')

# %%
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

viridis = cm.get_cmap('turbo', 256)
newcolors = viridis(np.linspace(0, 1, 256))
pink = np.array([0, 0, 0, 0])
newcolors[:25, :] = pink
newcmp = ListedColormap(newcolors)
# Out:
# /tmp/ipykernel_31307/3562279965.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   viridis = cm.get_cmap('turbo', 256)

# %%
satexample = np.load(f"../data/preprocessed/radar/{satFiles[20]}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[287], line 1
# ----> 1 satexample = np.load(f"../data/preprocessed/radar/{satFiles[20]}")
#
# File ~/miniconda3/envs/torch/lib/python3.10/site-packages/numpy/lib/npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     406     own_fid = True
#     408 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/preprocessed/radar/MSG3-SEVI-MSG15-0100-NA-20230402145741.904000000Z-NA.npy'

# %%
radexample = np.load(f"../data/preprocessed/radar/{radFiles[0]}")

# %%
plt.imshow(radexample, cmap='turbo')
plt.grid()
plt.axis('off')
plt.tight_layout()

# %%
bin_example = np.load(f"../data/preprocessed/radar-binned/{radFiles[0]}")

# %%
plt.imshow(bin_example, cmap='turbo')
plt.grid()
plt.axis('off')
plt.tight_layout()
