# %%
import os
import numpy as np
from tqdm import tqdm
import boto3
import matplotlib.pyplot as plt

# %%
original_file = "../data/preprocessed/radar/radar_nl_202303101155.npy"

# %%
binned_file = "../data/preprocessed/radar-binned/radar_nl_202303101155.npy"

# %%
og = np.load(original_file)
bin = np.load(binned_file).float()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[69], line 2
#       1 og = np.load(original_file)
# ----> 2 bin = np.load(binned_file).float()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'float'

# %%
plt.imshow(og, cmap="Blues")
plt.axis('off')
# Out:
# (-0.5, 1339.5, 1659.5, -0.5)

# %%
plt.imshow(bin, cmap="Blues")
plt.axis('off')
# Out:
# (-0.5, 1339.5, 1659.5, -0.5)
